# %% [markdown]
# Условие 3: 3 задача
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###Условие 1: Задача 1.
# Постройте график.
# Назовите график.
# Сделайте именование оси x и оси y.
# Сделайте выводы.
#
# 1.1. Скачать данные по ссылке https://gbcdn.mrgcdn.ru/uploads/asset/5298945/attachment/0bff2e29897ee28a9e482ff8499da7de.csv.
# 1.2 Изучите стоимости недвижимости.
# 1.3 Изучите распределение квадратуры жилой.
# 1.4 Изучите распределение года постройки.

# %%
# считываем данные.
df = pd.read_csv('../../data/kc_house_data.csv')
# df['price'] = df['price'] / 1000
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
plt.figure(figsize=(25,6))
plt.hist(df['price'], bins=200)
plt.locator_params (axis='x', nbins= 90 )
plt.xlabel('цена дома')
plt.ylabel('количество домов')
plt.title('плотность распределения цен на дома');

# %%
plt.figure(figsize=(20,20))
plt.boxplot(df['price'])
plt.locator_params (axis='y', nbins= 80 )
plt.ylabel('цена дома')
plt.title('плотность распределения цен на дома')
plt.grid();

# %% [markdown]
# Стоимости домов расположились, в основном, в интервале от 300000 до 700000. При этом присутствует много выбросов.

# %%
plt.figure(figsize=(25,6))
plt.hist(df['sqft_lot'], bins=300)
plt.locator_params (axis='x', nbins= 50 )
plt.xlabel('площадь дома')
plt.ylabel('количество домов')
plt.title('плотность распределения площади дома');

# %%
plt.figure(figsize=(20,20))
plt.boxplot(df['price'])
plt.locator_params (axis='y', nbins= 80 )
plt.ylabel('площадь дома')
plt.title('плотность распределения площадей домов')
plt.grid();

# %% [markdown]
# Площади домов расположились, в основном, в интервале от 250000 до 700000. При этом, так же как и со стоимостью домов, присутствует много выбросов.

# %%
plt.figure(figsize=(10,6))
plt.hist(df['yr_built'], bins=30)
plt.locator_params (axis='x', nbins= 30)
plt.xlabel('год постройки')
plt.ylabel('количество домов')
plt.title('плотность распределения годов постройки');

# %%
plt.figure(figsize=(10,5))
plt.boxplot(df['yr_built'])
plt.locator_params (axis='y', nbins= 30)
plt.ylabel('год постройки')
plt.title('плотность распределения годов постройки')
plt.grid();

# %% [markdown]
# Года постройки домов расположились, в основном, в интервале от 1950 до 2000. Выбросов нет.

# %% [markdown]
# ##Условие 2: 2 задача
# 2.1 Изучите распределение домов от наличия вида на набережную
# Постройте график
# Сделайте выводы
# 2.2 Изучите распределение этажей домов
# 2.2 Изучите распределение состояния домов

# %%
df['waterfront'] = list(map(lambda item: 'yes' if item == 1 else 'no', df['waterfront']))

# %%
df['waterfront'].value_counts()
# Out:
# no     21450
# yes      163
# Name: waterfront, dtype: int64

# %%
plt.figure(figsize=(4,6))
plt.bar(df['waterfront'].unique(), df['waterfront'].value_counts())
plt.xlabel('вид на набережную')
plt.ylabel('количество домов')
plt.title('зависимость  средней цены дома от вида из окна');

# %% [markdown]
# Вид на набережную имеют лишь 163 дома.

# %%
plt.figure(figsize=(10,6))
# plt.bar(df['floors'].unique(), df['floors'].value_counts())
sns.barplot(x=df['floors'].unique(), y=df['floors'].value_counts())
plt.locator_params (axis='x', nbins= 10)
plt.xlabel('количество этажей')
plt.ylabel('количество домов')
plt.title('Этажность домов');

# %% [markdown]
# Основная часть домов имеет один или два этажа.

# %%
plt.figure(figsize=(10,6))
# plt.plot(df.groupby('condition').agg({'price': ['mean']}))
sns.barplot(x=df['condition'].unique(), y=df['condition'].value_counts())
plt.xlabel('состояние дома')
plt.ylabel('средняя цена')
plt.title('зависимость  средней цены дома от его состояния')
plt.grid();

# %% [markdown]
# Более половины домов имеет среднее техническое состояние.

# %%
plt.figure(figsize=(10,6))
plt.bar(df['yr_built'].unique().sort(), df['yr_built']. value_counts().sort_index())
plt.xlabel('количество ванных комнат')
plt.ylabel('средняя цена')
plt.title('зависимость средней цены дома от количества ванных комнат')
plt.grid();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2458, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2457 try:
# -> 2458     left = x - width / 2
#    2459 except TypeError as e:
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 plt.bar(df['yr_built'].unique().sort(), df['yr_built']. value_counts().sort_index())
#       3 plt.xlabel('количество ванных комнат')
#       4 plt.ylabel('средняя цена')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2412, in bar(x, height, width, bottom, align, data, **kwargs)
# ...

# %%
df.groupby('yr_built').agg({'price': ['count']})
# Out:
#          price
#          count
# yr_built
# 1900        87
# 1901        29
# 1902        27
# 1903        46
# 1904        45
# ...        ...
# 2011       130
# 2012       170
# 2013       201
# 2014       559
# 2015        38
#
# [116 rows x 1 columns]

# %%
df['yr_built']. value_counts()[]
# Out:
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64

# %%
data = df.select_dtypes(include=['float32', 'float64', 'float16', 'int64'])

data.drop(['price', 'id'], axis=1, inplace=True)
data
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
# ...

# %%
data.hist(figsize=(16, 16), bins=50, grid=False);

# %%
plt.figure(figsize=(10,6))
plt.plot(df.groupby('bedrooms').agg({'price': ['mean']}))
plt.xlabel('количество спален')
plt.ylabel('средняя цена')
plt.title('зависимость срелней цены дома от количества спален')
plt.grid();

# %%
plt.figure(figsize=(10,6))
plt.plot(df.groupby('bathrooms').agg({'price': ['mean']}))
plt.xlabel('количество ванных комнат')
plt.ylabel('средняя цена')
plt.title('зависимость средней цены дома от количества ванных комнат')
plt.grid();

# %%
plt.figure(figsize=(10,6))
plt.plot(df.groupby('floors').agg({'price': ['mean']}))
plt.xlabel('количество этажей')
plt.ylabel('средняя цена')
plt.title('зависимость  средней цены дома от количества этажей')
plt.grid();

# %%
plt.figure(figsize=(10,6))
plt.plot(df.groupby('condition').agg({'price': ['mean']}))
plt.xlabel('состояние дома')
plt.ylabel('средняя цена')
plt.title('зависимость  средней цены дома от его состояния')
plt.grid();

# %%
plt.figure(figsize=(10,6))
plt.plot(df.groupby('waterfront').agg({'price': ['mean']}))
plt.xlabel('удалённость от побережья')
plt.ylabel('средняя цена')
plt.title('зависимость средней цены дома от удалённости от побережья')
plt.grid();

# %%
plt.figure(figsize=(10,6))
plt.plot(df.groupby('grade').agg({'price': ['mean']}))
plt.xlabel('категория')
plt.ylabel('средняя цена')
plt.title('зависимость средней цены дома от категории')
plt.grid();

# %% [markdown]
# #Вывод:
# Наибольшее влияние на цену дома оказывают его состояние и местность расположения.

# %%
plt.figure(figsize=(20,6))
plt.scatter(df['sqft_lot'].sort_values(ascending=False), df['price'])
plt.xlabel('общая площадь')
plt.ylabel('цена')
plt.title('зависимость цены дома от его площади')
plt.grid();

# %%
plt.figure(figsize=(10,6))
plt.plot(df.groupby('grade').agg({'sqft_lot': ['mean']}))
plt.xlabel('площадь')
plt.ylabel('категория')
plt.title('зависимость средней площади дома от категории')
plt.grid();

# %%
plt.figure(figsize=(20,6))
sns.histplot(df['sqft_lot'], bins=300)
plt.xlabel('площадь домов')
plt.ylabel('количество домов')
plt.title('плотность распределения площадей домов')
plt.grid();

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['bedrooms'].unique(), data['price']['mean'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# ...
